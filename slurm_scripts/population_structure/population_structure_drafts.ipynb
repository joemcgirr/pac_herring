# %%
# job = 'SFS'
# 
# vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_maxmiss0.5'
# 
# #sbatch submission script header
# script = 'script_' + job + '.sh'
# outfile = io.open(script,'w', newline='\n')    
# outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+job+'\n')
# outfile.write('#SBATCH --mem=16G \n')
# outfile.write('#SBATCH --ntasks=4 \n')
# outfile.write('#SBATCH -e '+job+'_%A_%a.err \n')
# outfile.write('#SBATCH --time=06-00:00  \n')
# outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
# outfile.write('#SBATCH -p high \n\n')
# 
# # format vcf header to avoid angsd error
# outfile.write('INFO=\'##INFO=<ID=INDEL,Number=0,Type=Flag,Description=\"\">\' \n')
# outfile.write('awk -v infohdr=$INFO \'/^#CHROM/ {print infohdr"\\n"$0} !/^#CHROM/\' /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf > /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.angsdSFS.vcf \n\n')
# 
# outfile.write('module load angsd \n')
# outfile.write('angsd -doSaf 1 -vcf-pl /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.angsdSFS.vcf -out /home/jamcgirr/ph/data/angsd/SFS/'+vcf_name+' -anc /home/jamcgirr/ph/data/c_harengus/c.harengus.fa \n')
# outfile.write('realSFS /home/jamcgirr/ph/data/angsd/SFS/'+vcf_name+'.saf.idx -P 4 -fold 1 > /home/jamcgirr/ph/data/angsd/SFS/'+vcf_name+'.sfs \n')
# outfile.write('realSFS saf2theta /home/jamcgirr/ph/data/angsd/SFS/'+vcf_name+'.saf.idx -sfs /home/jamcgirr/ph/data/angsd/SFS/'+vcf_name+'.sfs -outname /home/jamcgirr/ph/data/angsd/SFS/'+vcf_name+' \n')
# outfile.write('thetaStat do_stat /home/jamcgirr/ph/data/angsd/SFS/'+vcf_name+'.thetas.idx \n')
# 
# #run sbatch submission 
# outfile.write('\n\n#command to run: sbatch '+script)
# outfile.close()

## INFO='##INFO=<ID=INDEL,Number=0,Type=Flag,Description=\"\">'
## awk -v infohdr=$INFO '/^#CHROM/ {print infohdr"\n"$0} !/^#CHROM/' /home/jamcgirr/ph/data/vcfs/ph_filtered_snps_minDP350_maxDP2000_maf0.05_minQ30_maxmiss0.5.vcf > /home/jamcgirr/ph/data/vcfs/tester.vcf
## module load angsd
## angsd -doSaf 1 -vcf-pl /home/jamcgirr/ph/data/vcfs/tester.vcf -out test1 -anc /home/jamcgirr/ph/data/c_harengus/c.harengus.fa
## realSFS test1.saf.idx -P 1 -fold 1 > test1.sfs
## realSFS saf2theta test1.saf.idx -sfs test1.sfs -outname test1
## thetaStat do_stat test1.thetas.idx

# %%
# need to download outgroup individual (probably atl herring)

# git clone https://github.com/stamatak/standard-RAxML
# make -f Makefile.gcc

job = 'raxml'

vcf_name = 'ph_filtered_snps_minDP350_maxDP2000_maf0.05_minQ30_maxmiss0.5'
#vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_maxmiss0.5'
#vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ30_maxmiss0.5'


#sbatch submission script header
script = 'script_' + job + '.sh'
outfile = io.open(script,'w', newline='\n')    
outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+job+'\n')
outfile.write('#SBATCH --mem=16G \n')
outfile.write('#SBATCH --ntasks=4 \n')
outfile.write('#SBATCH -e '+job+'_%A_%a.err \n')
outfile.write('#SBATCH --time=24:00:00  \n')
outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
outfile.write('#SBATCH -p high \n\n')

outfile.write('module load python/2.7.6 \n')
outfile.write('python /home/jamcgirr/apps/vcf2phylip/vcf2phylip.py --input /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf \n')
outfile.write('/home/jamcgirr/apps/standard-RAxML/raxmlHPC -m GTRGAMMA -o VENA12 -p 12345 -s /pine/scr/j/m/jmcgirr/fitness_exp/vcfs/filtered_snps.MAF0.01_biallelic_no_missing.recode.min4.phy -# 10 -n filtered_snps.MAF0.01_biallelic_no_missing 


#run sbatch submission 
outfile.write('\n\n#command to run: sbatch '+script)
outfile.close()

# %%
job = 'rm_outlier_and_pca'

vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.5'

#sbatch submission script header
script = 'script_' + job + '.sh'
outfile = io.open(script,'w', newline='\n')    
outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+job+'\n')
outfile.write('#SBATCH --mem=16G \n')
outfile.write('#SBATCH --ntasks=8 \n')
outfile.write('#SBATCH -e '+job+'_%A_%a.err \n')
outfile.write('#SBATCH --time=72:00:00  \n')
outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
outfile.write('#SBATCH -p high \n\n')

# mv /home/jamcgirr/ph/scripts/plink/plates_1_through_5_rm.txt /home/jamcgirr/ph/scripts/plink/outliers_rm.txt

outfile.write('module load bcftools \n')
outfile.write('bcftools view -S /home/jamcgirr/ph/scripts/plink/outliers_rm.txt --threads 8 -O v /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf > /home/jamcgirr/ph/data/vcfs/'+vcf_name+'_outliers_rm.vcf \n')
outfile.write('module load vcftools \n')
outfile.write('vcftools --vcf /home/jamcgirr/ph/data/vcfs/'+vcf_name+'_outliers_rm.vcf --plink --out /home/jamcgirr/ph/data/vcfs/'+vcf_name+'_outliers_rm \n')
outfile.write('module load plink \n')
outfile.write('plink --file /home/jamcgirr/ph/data/vcfs/'+vcf_name+'_outliers_rm --pca --out /home/jamcgirr/ph/data/vcfs/'+vcf_name+'_outliers_rm \n') 
outfile.write('vcftools --vcf /home/jamcgirr/ph/data/vcfs/'+vcf_name+'_outliers_rm.vcf --BEAGLE-PL --chr chr1 --out /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm \n')
outfile.write('gzip /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL \n\n')

outfile.write('module load pcangsd \n')
outfile.write('python /home/jamcgirr/apps/pcangsd/pcangsd.py -beagle /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -o /home/jamcgirr/ph/data/angsd/PCAngsd/chr1_'+vcf_name+'_outliers_rm -threads 8 \n')
outfile.write('#python /home/jamcgirr/apps/pcangsd/pcangsd.py -beagle /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -o /home/jamcgirr/ph/data/angsd/PCAngsd/chr2_'+vcf_name+'_outliers_rm -threads 4 \n')
outfile.write('#python /home/jamcgirr/apps/pcangsd/pcangsd.py -beagle /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -o /home/jamcgirr/ph/data/angsd/PCAngsd/chr3_'+vcf_name+'_outliers_rm -threads 4 \n\n')

outfile.write('module load angsd \n')
outfile.write('NGSadmix -likes /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -K 2 -o /home/jamcgirr/ph/data/angsd/NGSadmix/k2_chr1_'+vcf_name+'_outliers_rm -P 8 \n')
outfile.write('NGSadmix -likes /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -K 3 -o /home/jamcgirr/ph/data/angsd/NGSadmix/k3_chr1_'+vcf_name+'_outliers_rm -P 8 \n')
outfile.write('NGSadmix -likes /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -K 4 -o /home/jamcgirr/ph/data/angsd/NGSadmix/k4_chr1_'+vcf_name+'_outliers_rm -P 8 \n')
outfile.write('NGSadmix -likes /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -K 5 -o /home/jamcgirr/ph/data/angsd/NGSadmix/k5_chr1_'+vcf_name+'_outliers_rm -P 8 \n')
outfile.write('NGSadmix -likes /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -K 6 -o /home/jamcgirr/ph/data/angsd/NGSadmix/k6_chr1_'+vcf_name+'_outliers_rm -P 8 \n')
outfile.write('NGSadmix -likes /home/jamcgirr/ph/data/vcfs/chr1_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -K 7 -o /home/jamcgirr/ph/data/angsd/NGSadmix/k7_chr1_'+vcf_name+'_outliers_rm -P 8 \n')


#run sbatch submission 
outfile.write('\n\n#command to run: sbatch '+script)
outfile.close()

# %%
job = '_rm_outlier_and_pca'

vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.5'
infiles = ["BC17","CA17","PWS","SS","TB","WA17"]

for infile in infiles:
    
    #sbatch submission script header
    script = 'script_' + infile + job + '.sh'
    outfile = io.open(script,'w', newline='\n') 
    jobname= infile + job   
    outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+jobname+'\n')
    outfile.write('#SBATCH --mem=8G \n')
    outfile.write('#SBATCH --ntasks=4 \n')
    outfile.write('#SBATCH -e '+jobname+'_%A_%a.err \n')
    outfile.write('#SBATCH --time=24:00:00 \n')
    outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
    outfile.write('#SBATCH -p high \n\n')
        
    outfile.write('module load bcftools \n')
    outfile.write('bcftools view -S /home/jamcgirr/ph/scripts/angsd/PCAngsd/outlier_rm/'+infile+'_outliers_rm.txt --threads 4 -O v /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf > /home/jamcgirr/ph/data/vcfs/split_pops/'+infile+'_'+vcf_name+'_outliers_rm.vcf \n')
    outfile.write('module load vcftools \n')
    outfile.write('vcftools --vcf /home/jamcgirr/ph/data/vcfs/split_pops/'+infile+'_'+vcf_name+'_outliers_rm.vcf --BEAGLE-PL --chr chr1 --out /home/jamcgirr/ph/data/vcfs/split_pops/chr1_'+infile+'_'+vcf_name+'_outliers_rm \n')
    outfile.write('gzip /home/jamcgirr/ph/data/vcfs/split_pops/chr1_'+infile+'_'+vcf_name+'_outliers_rm.BEAGLE.PL \n\n')
    
    outfile.write('module load pcangsd \n')
    outfile.write('python /home/jamcgirr/apps/pcangsd/pcangsd.py -beagle /home/jamcgirr/ph/data/vcfs/split_pops/chr1_'+infile+'_'+vcf_name+'_outliers_rm.BEAGLE.PL.gz -o /home/jamcgirr/ph/data/angsd/PCAngsd/chr1_'+infile+'_'+vcf_name+'_outliers_rm -threads 4 \n')

    #run sbatch submission 
    outfile.write('\n\n#command to run: sbatch '+script)
    outfile.close()
    
#EST run time ~30min

# %%
job = '_fst_8x8'

vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.
comps =["TB91_6_3_v_TB96_9_3_v_TB96_10_6","TB91_7_5_v_TB96_9_3_v_TB96_10_6","TB91_9_1_v_TB96_9_3_v_TB96_10_6","TB91_11_7_v_TB96_9_3_v_TB96_10_6","TB91_14_4_v_TB96_9_3_v_TB96_10_6","TB91_15_1_v_TB96_9_3_v_TB96_10_6","TB91_17_4_v_TB96_9_3_v_TB96_10_6","TB91_19_1_v_TB96_9_3_v_TB96_10_6","TB91_6_3_v_TB96_12_4_v_TB96_14_5","TB91_7_5_v_TB96_12_4_v_TB96_14_5","TB91_9_1_v_TB96_12_4_v_TB96_14_5","TB91_11_7_v_TB96_12_4_v_TB96_14_5","TB91_14_4_v_TB96_12_4_v_TB96_14_5","TB91_15_1_v_TB96_12_4_v_TB96_14_5","TB91_17_4_v_TB96_12_4_v_TB96_14_5","TB91_19_1_v_TB96_12_4_v_TB96_14_5","TB91_6_3_v_TB96_16_6_v_TB96_17_5","TB91_7_5_v_TB96_16_6_v_TB96_17_5","TB91_9_1_v_TB96_16_6_v_TB96_17_5","TB91_11_7_v_TB96_16_6_v_TB96_17_5","TB91_14_4_v_TB96_16_6_v_TB96_17_5","TB91_15_1_v_TB96_16_6_v_TB96_17_5","TB91_17_4_v_TB96_16_6_v_TB96_17_5","TB91_19_1_v_TB96_16_6_v_TB96_17_5","TB91_6_3_v_TB96_19_8_v_TB96_20_2","TB91_7_5_v_TB96_19_8_v_TB96_20_2","TB91_9_1_v_TB96_19_8_v_TB96_20_2","TB91_11_7_v_TB96_19_8_v_TB96_20_2","TB91_14_4_v_TB96_19_8_v_TB96_20_2","TB91_15_1_v_TB96_19_8_v_TB96_20_2","TB91_17_4_v_TB96_19_8_v_TB96_20_2","TB91_19_1_v_TB96_19_8_v_TB96_20_2"]

for comp in comps:
    
    #sbatch submission script header
    script = 'script_' + comp + job + '.sh'
    outfile = io.open(script,'w', newline='\n') 
    jobname= comp + job   
    outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+jobname+'\n')
    outfile.write('#SBATCH --mem=8G \n')
    outfile.write('#SBATCH --ntasks=4 \n')
    outfile.write('#SBATCH -e '+jobname+'_%A_%a.err \n')
    outfile.write('#SBATCH --time=24:00:00 \n')
    outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
    outfile.write('#SBATCH -p high \n\n')
    
    pops = ''.join(comp).split("_v_")
    temp_dir = '/home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/'+pops[0]+'_'+pops[1]+'_'+pops[2]+'/'
    
    outfile.write('module load samtools \n')
    outfile.write('module load bcftools \n\n')
    
    outfile.write('mkdir '+temp_dir+' \n\n')
    
    outfile.write('bcftools view -S /home/jamcgirr/ph/scripts/angsd/SFS/SFS_by_pop/SFS_by_row/'+pops[0]+'.txt -Ov /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf > '+temp_dir+pops[0]+'.vcf \n')
    outfile.write('bcftools view -S /home/jamcgirr/ph/scripts/angsd/SFS/SFS_by_pop/SFS_by_row/'+pops[1]+'.txt -Ov /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf > '+temp_dir+pops[1]+'.vcf \n')
    outfile.write('bcftools view -S /home/jamcgirr/ph/scripts/angsd/SFS/SFS_by_pop/SFS_by_row/'+pops[2]+'.txt -Ov /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf > '+temp_dir+pops[2]+'.vcf \n\n')

    outfile.write('/home/jamcgirr/apps/angsd/angsd -doSaf 1 -vcf-pl '+temp_dir+pops[0]+'.vcf -out '+temp_dir+pops[0]+' -anc /home/jamcgirr/ph/data/c_harengus/c.harengus.fa \n')
    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS '+temp_dir+pops[0]+'.saf.idx -P 4 -fold 1 > '+temp_dir+pops[0]+'.sfs \n')
    outfile.write('/home/jamcgirr/apps/angsd/angsd -doSaf 1 -vcf-pl '+temp_dir+pops[1]+'.vcf -out '+temp_dir+pops[1]+' -anc /home/jamcgirr/ph/data/c_harengus/c.harengus.fa \n')
    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS '+temp_dir+pops[1]+'.saf.idx -P 4 -fold 1 > '+temp_dir+pops[1]+'.sfs \n')
    outfile.write('/home/jamcgirr/apps/angsd/angsd -doSaf 1 -vcf-pl '+temp_dir+pops[2]+'.vcf -out '+temp_dir+pops[2]+' -anc /home/jamcgirr/ph/data/c_harengus/c.harengus.fa \n')
    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS '+temp_dir+pops[2]+'.saf.idx -P 4 -fold 1 > '+temp_dir+pops[2]+'.sfs \n')
    
    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS '+temp_dir+pops[0]+'.saf.idx '+temp_dir+pops[1]+'.saf.idx -P 4 > '+temp_dir+pops[0]+'_'+pops[1]+'.ml \n')
    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS '+temp_dir+pops[0]+'.saf.idx '+temp_dir+pops[2]+'.saf.idx -P 4 > '+temp_dir+pops[0]+'_'+pops[2]+'.ml \n')
    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS '+temp_dir+pops[1]+'.saf.idx '+temp_dir+pops[2]+'.saf.idx -P 4 > '+temp_dir+pops[1]+'_'+pops[2]+'.ml \n\n')

    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS fst index '+temp_dir+pops[0]+'.saf.idx '+temp_dir+pops[1]+'.saf.idx '+temp_dir+pops[2]+'.saf.idx -sfs '+temp_dir+pops[0]+'_'+pops[1]+'.ml -sfs '+temp_dir+pops[0]+'_'+pops[2]+'.ml -sfs '+temp_dir+pops[1]+'_'+pops[2]+'.ml -fstout '+temp_dir+pops[0]+'_'+pops[1]+'_'+pops[2]+'  \n')
    outfile.write('/home/jamcgirr/apps/angsd/misc/realSFS fst stats2 '+temp_dir+pops[0]+'_'+pops[1]+'_'+pops[2]+'.fst.idx -win 50000 -step 10000 > '+temp_dir+'fst_50kb_win_'+pops[0]+'_'+pops[1]+'_'+pops[2]+'.txt \n\n')

    outfile.write('awk \'{ total += $5 } END { print total/NR }\' '+temp_dir+'fst_50kb_win_'+pops[0]+'_'+pops[1]+'_'+pops[2]+'.txt > /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/means/fst_50kb_win_genome_mean_'+pops[0]+'_'+pops[1]+'.txt \n')
    outfile.write('awk \'{ total += $6 } END { print total/NR }\' '+temp_dir+'fst_50kb_win_'+pops[0]+'_'+pops[1]+'_'+pops[2]+'.txt > /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/means/fst_50kb_win_genome_mean_'+pops[0]+'_'+pops[2]+'.txt \n')
    outfile.write('awk \'{ total += $7 } END { print total/NR }\' '+temp_dir+'fst_50kb_win_'+pops[0]+'_'+pops[1]+'_'+pops[2]+'.txt > /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/means/fst_50kb_win_genome_mean_'+pops[1]+'_'+pops[2]+'.txt \n\n')
    
    outfile.write('rm -r '+temp_dir+' \n\n')

    #run sbatch submission 
    outfile.write('\n\n#command to run: sbatch '+script)
    outfile.close()

# %%
job = 'vcftools_fst'

vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.5'

#sbatch submission script header
script = 'script_' + job + '.sh'
outfile = io.open(script,'w', newline='\n')    
outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+job+'\n')
outfile.write('#SBATCH --mem=16G \n')
outfile.write('#SBATCH --ntasks=1 \n')
outfile.write('#SBATCH -e '+job+'_%A_%a.err \n')
outfile.write('#SBATCH --time=48:00:00  \n')
outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
outfile.write('#SBATCH -p high \n\n')


outfile.write('module load vcftools \n')
outfile.write('#vcftools --vcf /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf --keep /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/CA17_WA17_plates_1_5_rm.txt --out /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/vcftools_fst_CA17_v_WA17 --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/CA17_plates_1_through_5_rm.txt --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/WA17_plates_1_through_5_rm.txt \n')
outfile.write('#vcftools --vcf /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf --keep /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/PWS07_PWS91_plates_1_5_rm.txt --out /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/vcftools_fst_PWS07_v_PWS91 --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/PWS07_plates_1_through_5_rm.txt --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/PWS91_plates_1_through_5_rm.txt \n')
outfile.write('vcftools --vcf /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf --keep /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/TB91_TB96_plates_1_5_rm.txt --out /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/vcftools_fst_TB91_v_TB96 --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/TB96_plates_1_through_5_rm.txt --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/TB91_plates_1_through_5_rm.txt \n')
outfile.write('vcftools --vcf /home/jamcgirr/ph/data/vcfs/'+vcf_name+'.vcf --keep /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/TB91_TB06_plates_1_5_rm.txt --out /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/vcftools_fst_TB91_v_TB06 --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/TB06_plates_1_through_5_rm.txt --weir-fst-pop /home/jamcgirr/ph/data/vcfs/split_pops/split_by_row/TB91_plates_1_through_5_rm.txt \n')

#run sbatch submission 
outfile.write('\n\n#command to run: sbatch '+script)
outfile.close()

# %%
# outlier_rm same as plates_1_5_rm

job = '_vcftools_pi'
vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.5_plates_1_5_rm'
infiles = ["BC17","CA17","PWS07","PWS17","PWS91","PWS96","SS06","SS17","SS96","TB06","TB17","TB91","TB96","WA17"]
vcf_dir = '/home/jamcgirr/ph/data/vcfs/split_pops/'

for infile in infiles:
    
    #sbatch submission script header
    script = 'script_' + infile + job + '.sh'
    outfile = io.open(script,'w', newline='\n') 
    jobname= infile + job   
    outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+jobname+'\n')
    outfile.write('#SBATCH --mem=8G \n')
    outfile.write('#SBATCH --ntasks=1 \n')
    outfile.write('#SBATCH -e '+jobname+'_%A_%a.err \n')
    outfile.write('#SBATCH --time=24:00:00 \n')
    outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
    outfile.write('#SBATCH -p high \n\n')
    
    outfile.write('module load vcftools \n')
    outfile.write('vcftools --vcf '+vcf_dir+'population_'+infile+'_'+vcf_name+'.vcf --window-pi 50000 --out /home/jamcgirr/ph/data/vcfs/split_pops/vcftools_pi/pi_50kb_win_'+infile+'_'+vcf_name+'.txt \n')


    #run sbatch submission 
    outfile.write('\n\n#command to run: sbatch '+script)
    outfile.close()

# %%
job = 'smcpp_test'

vcf_name = 'ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.5_outliers_rm'
vcf_dir = '/home/jamcgirr/ph/data/vcfs/'

#sbatch submission script header
script = 'script_' + job + '.sh'
outfile = io.open(script,'w', newline='\n')    
outfile.write('#!/bin/bash\n\n#SBATCH --job-name='+job+'\n')
outfile.write('#SBATCH --mem=16G \n')
outfile.write('#SBATCH --ntasks=4 \n')
outfile.write('#SBATCH -e '+job+'_%A_%a.err \n')
outfile.write('#SBATCH --time=24:00:00  \n')
outfile.write('#SBATCH --mail-user=jamcgirr@ucdavis.edu ##email you when job starts,ends,etc\n#SBATCH --mail-type=ALL\n')
outfile.write('#SBATCH -p high \n\n')

outfile.write('source /home/jamcgirr/apps/my_python3.7/bin/activate \n')

outfile.write('module load mpfr \n')
outfile.write('module load gmp \n')
outfile.write('module load gsl \n')
outfile.write('#module load tabix \n')

outfile.write('#bgzip /home/jamcgirr/ph/data/vcfs/ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.5_outliers_rm.vcf \n')
outfile.write('#tabix -p vcf /home/jamcgirr/ph/data/vcfs/ph_filtered_snps_minDP600_maxDP2000_maf0.05_minQ20_minMQ30_maxmiss0.5_outliers_rm.vcf.gz \n')

outfile.write('smc++ vcf2smc '+vcf_dir+vcf_name+'.vcf.gz /home/jamcgirr/ph/data/smcpp/pop1.smc.gz chr1 pop1:0385_TB17,0386_TB17 -v -v \n')
outfile.write('smc++ vcf2smc '+vcf_dir+vcf_name+'.vcf.gz /home/jamcgirr/ph/data/smcpp/pop2.smc.gz chr1 pop2:0329_PWS17,0330_PWS17 \n')
outfile.write('#smc++ estimate -o /home/jamcgirr/ph/data/smcpp/pop1/ 2.0e-9 /home/jamcgirr/ph/data/smcpp/pop1.smc.gz \n')
outfile.write('#smc++ estimate -o /home/jamcgirr/ph/data/smcpp/pop2/ 2.0e-9 /home/jamcgirr/ph/data/smcpp/pop2.smc.gz \n')

outfile.write('#smc++ vcf2smc '+vcf_dir+vcf_name+'.vcf.gz /home/jamcgirr/ph/data/smcpp/pop12.smc.gz chr1 pop1:0385_TB17,0386_TB17 pop2:0329_PWS17,0330_PWS17 \n')
outfile.write('#smc++ vcf2smc '+vcf_dir+vcf_name+'.vcf.gz /home/jamcgirr/ph/data/smcpp/pop21.smc.gz chr1 pop2:0329_PWS17,0330_PWS17 pop1:0385_TB17,0386_TB17 \n')

outfile.write('#smc++ split -o /home/jamcgirr/ph/data/smcpp/ /home/jamcgirr/ph/data/smcpp/pop1/model.final.json /home/jamcgirr/ph/data/smcpp/pop2/model.final.json /home/jamcgirr/ph/data/smcpp/*.smc.gz \n')
outfile.write('#smc++ plot joint.pdf /home/jamcgirr/ph/data/smcpp/model.final.json \n')
              
outfile.write('\n\n#command to run: sbatch '+script)
outfile.close()
